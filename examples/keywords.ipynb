# %% [markdown]
# **Подключение к базе данных**
#
# В .env файле указывается строка подключения к базе данных PostgreSQL (см. .env.example). Данная строка используется в качестве параметра при инициализации класса для работы с БД (Database).

# %%
from database import Database
from dotenv import load_dotenv, find_dotenv
from os import getenv
import logging.config

load_dotenv(find_dotenv())

logging_config = {
    'version': 1,
    'disable_existing_loggers': False,

    'formatters': {
        'default_formatter': {
            'format': '[%(levelname)s] %(message)s'
        },
    },

    'handlers': {
        'stream_handler': {
            'class': 'logging.StreamHandler',
            'formatter': 'default_formatter',
        },
    },

    'loggers': {
        'my_logger': {
            'handlers': ['stream_handler'],
            'level': 'INFO',
            'propagate': False
        }
    }
}

logging.config.dictConfig(logging_config)
logger = logging.getLogger('my_logger')

db = Database(getenv('DATABASE_URL'), logger)
# Out:
# [INFO] a connection to the database has been established

# %% [markdown]
# Получение списка публикаций пользователя Instagram.
#
# *Замечание: информация о публикациях должна быть предварительно собрана с использованием InstagramScraper и загружена в БД (DATABASE_URL).*

# %%
posts = db.get_user_posts('https://www.instagram.com/russkih_aleksey/')
for post in posts[:5]:
    print(f'URL поста: {post.url}\n'
          f'Содержание поста: {post.text}\n'
          f'Время публикации поста: {post.time}\n'
          f'Хеш-теги поста: {post.tags}\n'
          f'Упоминания в посте: {post.links}',
          end='\n\n')
# Out:
# URL поста: https://www.instagram.com/p/CX097AWNTm2/
# Содержание поста: С большим вниманием смотрел пресс-конференцию Президента России Владимира Владимировича Путина. Глава государства затронул много важных тем.
#
# 🔹ИНСТРУМЕНТЫ ДЛЯ РОСТА ЭКОНОМИКИ
#
# Президент обозначил, какие есть драйверы для экономического роста в условиях пандемии, какие существуют инструменты поддержки на федеральном уровне. Наша задача активно входить во все федеральные программы и улучшать инфраструктуру в регионе. В этом году Ульяновская область получила мощную поддержку от Правительства РФ на развитие индустриальных парков. А это новые предприятия, новые рабочие места для людей.
#
# 🔹ОБЕСПЕЧЕНИЕ ИНФРАСТРУКТУРЫ ДЛЯ ЗЕМЕЛЬНЫХ УЧАСТКОВ МНОГОДЕТНЫХ
#
# Ещё одна актуальная для Ульяновской области тема - обеспечение качественной инфраструктурой земельных участков для многодетных семей. Особенно остро проблема стоит в крупнейших городах региона – Ульяновске и Димитровграде.
#
# Важно, что Президент обратил внимание на то, что в качественном решении этого вопроса регионам необходима федеральная поддержка. Средства есть. Главное, качественно подготовить заявки на их получение и грамотно реализовать. Будем над этим плотно работать с федеральным центром.
#
# 🔹ПЕРЕСЕЛЕНИЕ ИЗ АВАРИЙНОГО ЖИЛЬЯ
#
# Ещё один важный вопрос – переселение граждан из аварийного жилья. Президент ответил на вопрос, который волнует многих! Для переселения людей из домов, признанных аварийным после 1 января 2017 года, будут выделяться деньги из федерального бюджета. Программа готовится.
#
# Что это значит для Ульяновской области? Мы досрочно, на два года раньше, сейчас обязаны закрыть проблему по переселению жителей Ульяновской области из аварийного жилья  по текущей программе. По домам, которые признаны аварийными до 1 января 2017 года, нас активно поддерживает Фонд ЖКХ. Быстро и качественно завершив работу по этим домам, будем обязательно заявляться в новую программу для получения федеральной поддержки.
# Время публикации поста: 2021-12-23 14:29:07+00:00
# Хеш-теги поста: []
# Упоминания в посте: []
#
# URL поста: https://www.instagram.com/p/CX3N4xoNvUO/
# Содержание поста: Год назад Президент России Владимир Владимирович Путин присвоил Ульяновску Почётное звание «Город трудовой доблести». Это высочайшее и поистине народное признание трудового героизма и самоотверженности жителей региона, их вклада в Великую Победу.
#
# В этом году исполнилось 80 лет с начала Великой Отечественной войны. Не найдется в стране ни одной семьи, которой не коснулась бы война. Открыв стелу «Город трудовой доблести», мы увековечиваем подвиг каждого героя! Отдаём дань уважения всем ульяновцам, которые в годы войны, не щадя сил, вне зависимости от возраста, день и ночь стояли у станков, работали в полях, обеспечивая фронт всем необходимым.
#
# Наша стела — это память, воплощенная в камне. Память о предприятиях и их коллективах, которые были эвакуированы из прифронтовых территорий и в кратчайшие сроки перестроили свое производство на военный лад. Память о героическом труде медицинских работников тыловых госпиталей, о вкладе сельчан и простых жителей.
# Мы должны чтить все эти подвиги.
# Время публикации поста: 2021-12-24 11:27:07+00:00
# Хеш-теги поста: []
# Упоминания в посте: []
#
# URL поста: https://www.instagram.com/p/CX3ZqJ_NlZg/
# Содержание поста: Сегодня транспортный парк муниципальных образований Ульяновской области пополнился 14 новыми автобусами 👍
#
# В самое ближайшее время они выйдут на внутрирайонные маршруты, а также на маршруты в направлении областного центра.
#
# Сегодняшнее пополнение – далеко не последнее. Всего по региональной госпрограмме планируется приобрести 320 единиц пассажирского транспорта: 240 автобусов, 50 трамваев и 30 троллейбусов. Закупать начнём уже в следующем году. Важно, чтобы жители почувствовали улучшение в работе общественного транспорта. Сейчас это одна из самых острых проблем для нашего региона.
# Время публикации поста: 2021-12-24 13:09:58+00:00
# Хеш-теги поста: []
# Упоминания в посте: []
#
# URL поста: https://www.instagram.com/p/CX3tuFkt1Uu/
# Содержание поста: ❗️Считаю, что необходимо сделать патент за 1 рубль для сельских торговых точек. Будем выходить с такой инициативой к депутатам Законодательного собрания Ульяновской области. Решение актуально в свете повышения цен на товары первой необходимости и продукты питания.
#
# 🔹Планируем снизить стоимость патента для магазинов сельских населенных пунктов и торговых точек Ульяновска, Димитровграда, Новоульяновска и Чердаклов. Будет правильно, если по четырем вышеуказанным городским округам предприниматели розничной торговли смогут взять один патент, не разделяя его на несколько единиц.
#
# 🔹Вопрос по патентам сейчас волнует предпринимательское сообщество, поэтому по моему поручению создана рабочая группа, которая очень детально рассматривает ситуацию в разрезе различных отраслей. Как доложил мне сегодня Председатель Правительства Владимир Разумков, на днях вопрос возможных изменений в закон о патентной системе налогообложения рассмотрели на совместном совещании с участием депутатов Законодательного собрания и общественных организации. По итогу обсуждения было принято решение, что для сферы грузоперевозок изменения необходимы. Сегодня поручил по этой отрасли провести дополнительный анализ. Важно, чтобы налоговая нагрузка на грузоперевозчиков не превышала средних значений в субъектах ПФО и способствовала легализации занятости в этой сфере.
#
# 🔹Помимо этого, обсудили подготовку нового пакета антикризисных мер для предпринимателей. Необходимо детально обсудить с бизнесом предлагаемые меры поддержки. Они должны быть рабочими инструментами. Планируется, что с января первая часть финансирования мер поддержки составит около ста млн рублей, за весь 2022 год – не менее 200 млн.
# Время публикации поста: 2021-12-24 16:05:16+00:00
# Хеш-теги поста: []
# Упоминания в посте: []
#
# URL поста: https://www.instagram.com/p/CX5Vinjt546/
# Содержание поста: Дорогие Матвей, Максим, Серёжа и Даша! Рад был познакомиться и исполнить ваши новогодние желания. Подарки выбирал сам. Надеюсь, всё понравилось🙂 С наступающим Новым годом!
#
# «Ёлка желаний» дарит детям праздник, а взрослым напоминает о том, что в наших силах сотворить пусть небольшое, но очень важное для детского сердца чудо.
# Время публикации поста: 2021-12-25 07:12:28+00:00
# Хеш-теги поста: []
# Упоминания в посте: []

# %% [markdown]
# Получение списка комментариев к публикациям пользователя Instagram.
#
# *Замечание: информация о комментариях должна быть предварительно собрана с использованием InstagramScraper  и загружена в БД (DATABASE_URL).*

# %%
comments = db.get_user_posts_comments('https://www.instagram.com/russkih_aleksey/')
for comment in comments[:5]:
    print(f'URL комментария: {comment.url}\n'
          f'URL автора комментария: {comment.owner_url}\n'
          f'Содержание комментария: {comment.text}\n'
          f'Время публикации комментария: {comment.time}\n'
          f'Хеш-теги комментария: {comment.tags}\n'
          f'Упоминания в комментарии: {comment.links}',
          end='\n\n')
# Out:
# URL комментария: https://www.instagram.com/p/CX097AWNTm2/c/18220123078096586/
# URL автора комментария: https://www.instagram.com/sepsiz86/
# Содержание комментария: Алексей Юрьевич,что насчёт канализации на амурской думаете делать,как будем решать проблему?
# Время публикации комментария: 2021-12-23 10:30:24+00:00
# Хеш-теги комментария: []
# Упоминания в комментарии: []
#
# URL комментария: https://www.instagram.com/p/CX097AWNTm2/c/17912435033110175/
# URL автора комментария: https://www.instagram.com/olga_elka86/
# Содержание комментария: Как быть тем многодетным которых вообще не ставят на очередь на землю из за того что один ребёнок на территории папы прописан???Глупые критерии!
# Время публикации комментария: 2021-12-23 10:39:19+00:00
# Хеш-теги комментария: []
# Упоминания в комментарии: []
#
# URL комментария: https://www.instagram.com/p/CX097AWNTm2/c/17903516834289944/
# URL автора комментария: https://www.instagram.com/valnatal1969/
# Содержание комментария: Остановите ценыыыыыыыы!!!!!!!! Скоро по меру пойдём!😢
# Время публикации комментария: 2021-12-23 10:42:19+00:00
# Хеш-теги комментария: []
# Упоминания в комментарии: []
#
# URL комментария: https://www.instagram.com/p/CX097AWNTm2/c/17999975284378782/
# URL автора комментария: https://www.instagram.com/ekaterinaka13/
# Содержание комментария: Соглашусь Остановите цены сегодня зашла с ума сойти капуста 50 руб килограмм в Гулливере сахар за 50 руб перевалил 900 г просто беспредел хлеб дорожает основные виды продуктов, которые мы покупаем это первая необходимость и она недоступна со мной думаю согласятся все особенно пенсионеры🔥🔥🔥
# Время публикации комментария: 2021-12-23 10:51:44+00:00
# Хеш-теги комментария: []
# Упоминания в комментарии: []
#
# URL комментария: https://www.instagram.com/p/CX097AWNTm2/c/17943262969749387/
# URL автора комментария: https://www.instagram.com/eseer2013/
# Содержание комментария: Добрый вечер, круглосуточная аптека хотя бы одна нужна в дальнем засвияжье. Спасибо за внимание 👋
# Время публикации комментария: 2021-12-23 10:54:02+00:00
# Хеш-теги комментария: []
# Упоминания в комментарии: []

# %% [markdown]
# Подключение пакета для анализа текстов, [srsparser](https://github.com/Text-Analysis/srsparser), который содержит методы предобработки текста, извлечения ключевых слов и получения TF-IDF весов слов.

# %%
# %pip install srsparser --upgrade
# Out:
# Requirement already satisfied: srsparser in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (1.3.11)
# Requirement already satisfied: prettytable>=3.0.0 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (3.1.1)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (3.7)
# Requirement already satisfied: pymongo>=4.0.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (4.0.1)
# Requirement already satisfied: python-docx>=0.8.11 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (0.8.11)
# Requirement already satisfied: dnspython>=2.2.0 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (2.2.0)
# Requirement already satisfied: pullenti>=4.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (4.1)
# Requirement already satisfied: anytree>=2.8.0 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (2.8.0)
# Requirement already satisfied: pymorphy2>=0.9.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (0.9.1)
# Requirement already satisfied: gensim>=4.1.2 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from srsparser) (4.1.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from anytree>=2.8.0->srsparser) (1.16.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from gensim>=4.1.2->srsparser) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from gensim>=4.1.2->srsparser) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from gensim>=4.1.2->srsparser) (1.21.5)
# Requirement already satisfied: Cython==0.29.23 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from gensim>=4.1.2->srsparser) (0.29.23)
# Requirement already satisfied: joblib in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from nltk>=3.6.7->srsparser) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from nltk>=3.6.7->srsparser) (2022.1.18)
# Requirement already satisfied: tqdm in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from nltk>=3.6.7->srsparser) (4.62.3)
# Requirement already satisfied: click in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from nltk>=3.6.7->srsparser) (8.0.4)
# Requirement already satisfied: importlib-metadata in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from prettytable>=3.0.0->srsparser) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from prettytable>=3.0.0->srsparser) (0.2.5)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from pymorphy2>=0.9.1->srsparser) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from pymorphy2>=0.9.1->srsparser) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from pymorphy2>=0.9.1->srsparser) (0.7.2)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from python-docx>=0.8.11->srsparser) (4.8.0)
# Requirement already satisfied: colorama in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from click->nltk>=3.6.7->srsparser) (0.4.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from importlib-metadata->prettytable>=3.0.0->srsparser) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\f0rge\pycharmprojects\posts-scraper\venv\lib\site-packages (from importlib-metadata->prettytable>=3.0.0->srsparser) (3.7.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\f0rge\PycharmProjects\posts-scraper\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Извлечение из списка полученных комментариев по пользователю содержимого комментариев, длина которых больше 20 символов, убрав из содержания упоминания пользователей Instagram.

# %%
filtered_comments = [Database.remove_links_from_comment(comment)
                     for comment in comments
                     if len(comment.text) > 20]

comments_contents = [comment.text for comment in filtered_comments]

# %% [markdown]
# Инициализация класса, ответствнного за обработку текста на естественном языке (включает в себя методы извлечения ключевых слов с использованием pullenti, построение tf-idf модели с использованием gensim и др.)

# %%
from srsparser import NLProcessor

nlp = NLProcessor(init_pullenti=True)

# %% [markdown]
# Построение на основе отобранного содержимого комментариев TF-IDF модели и получение весов слов в этмх комментариях. В качестве примера осуществляется вывод первых 10 элементов.

# %%
comments_tf_idf_weights = nlp.get_tf_idf_weights(comments_contents)

n = 10 if len(comments_tf_idf_weights) >= 10 else len(comments_tf_idf_weights)
for i in range(n):
    print('Комментарий:', comments_contents[i])
    print('TF-IDF веса слов в комментарии:', comments_tf_idf_weights[i], end='\n\n')
# Out:
# Комментарий: Алексей Юрьевич,что насчёт канализации на амурской думаете делать,как будем решать проблему?
# TF-IDF веса слов в комментарии: [['амурской', 0.527], ['насчёт', 0.428], ['решать', 0.341], ['канализация', 0.332], ['думать', 0.304], ['делать', 0.242], ['быть', 0.204], ['проблема', 0.204], ['юриевич', 0.199], ['алексей', 0.197]]
#
# Комментарий: Как быть тем многодетным которых вообще не ставят на очередь на землю из за того что один ребёнок на территории папы прописан???Глупые критерии!
# TF-IDF веса слов в комментарии: [['глупый', 0.394], ['критерий', 0.382], ['папа', 0.372], ['прописать', 0.372], ['земля', 0.303], ['многодетный', 0.296], ['ставить', 0.29], ['очередь', 0.203], ['территория', 0.203], ['вообще', 0.176], ['который', 0.149], ['ребёнок', 0.148]]
#
# Комментарий: Остановите ценыыыыыыыы!!!!!!!! Скоро по меру пойдём!😢
# TF-IDF веса слов в комментарии: [['ценыыыыыыы', 0.598], ['остановить', 0.472], ['поидти', 0.454], ['скоро', 0.379], ['мера', 0.264]]
#
# Комментарий: Соглашусь Остановите цены сегодня зашла с ума сойти капуста 50 руб килограмм в Гулливере сахар за 50 руб перевалил 900 г просто беспредел хлеб дорожает основные виды продуктов, которые мы покупаем это первая необходимость и она недоступна со мной думаю согласятся все особенно пенсионеры🔥🔥🔥
# TF-IDF веса слов в комментарии: [['согласиться', 0.397], ['руб', 0.319], ['перевалить', 0.236], ['дорожать', 0.217], ['килограмм', 0.217], ['недоступный', 0.217], ['соить', 0.217], ['зайти', 0.199], ['капуста', 0.199], ['ум', 0.183], ['основной', 0.18], ['сахар', 0.177], ['остановить', 0.171], ['мной', 0.169], ['хлеб', 0.161], ['беспредел', 0.155], ['гулливер', 0.154], ['необходимость', 0.151], ['покупать', 0.15], ['продукт', 0.15], ['пенсионер', 0.138], ['особенно', 0.129], ['думать', 0.125], ['вид', 0.121], ['цена', 0.121], ['первый', 0.107], ['сегодня', 0.103], ['просто', 0.093], ['который', 0.075], ['это', 0.057]]
#
# Комментарий: Добрый вечер, круглосуточная аптека хотя бы одна нужна в дальнем засвияжье. Спасибо за внимание 👋
# TF-IDF веса слов в комментарии: [['аптека', 0.446], ['круглосуточный', 0.429], ['дальний', 0.353], ['засвияжий', 0.317], ['вечер', 0.307], ['хотя', 0.269], ['нужный', 0.259], ['внимание', 0.229], ['один', 0.22], ['добрый', 0.17], ['спасибо', 0.169]]
#
# Комментарий: Землю то не дают. Какие инфраструктуры?
# TF-IDF веса слов в комментарии: [['инфраструктура', 0.612], ['земля', 0.56], ['давать', 0.466], ['какой', 0.307]]
#
# Комментарий: Вы бы эту инфраструктуру сделали в новой жизни! Должна была быть поликлиника! И где она???? Только болтать можете. Огромный район. Из инфраструктуры ноль. А насчёт инфраструктуры где дали земли многодетным. Так когда вообще последний раз вообще её давали??? 7лет назад?
# TF-IDF веса слов в комментарии: [['инфраструктура', 0.643], ['болтать', 0.303], ['последнии', 0.236], ['вообще', 0.228], ['насчёт', 0.227], ['ноль', 0.205], ['земля', 0.196], ['многодетный', 0.192], ['новой', 0.192], ['назад', 0.17], ['давать', 0.163], ['жизнь', 0.151], ['огромный', 0.146], ['сделать', 0.128], ['дать', 0.123], ['должный', 0.122], ['поликлиника', 0.115], ['раион', 0.096], ['мочь', 0.092], ['год', 0.07]]
#
# Комментарий:  нам дали землю- 15 соток в чистом поле, коммуникаций нет никаких, электричества, воды, газа. Зато налог земельный платим. Одна показуха и все!
# TF-IDF веса слов в комментарии: [['сотка', 0.385], ['электричество', 0.324], ['показуха', 0.299], ['коммуникация', 0.288], ['поле', 0.263], ['чистый', 0.263], ['земля', 0.249], ['земельный', 0.241], ['зато', 0.238], ['налог', 0.214], ['никакой', 0.201], ['вода', 0.198], ['газ', 0.188], ['платить', 0.186], ['дать', 0.156], ['один', 0.148], ['мы', 0.135]]
#
# Комментарий: То что предыдущий губернатор наобещал и исчез, вряд ли вина Русских. Тем более если по 7 лет не решалось
# TF-IDF веса слов в комментарии: [['вино', 0.436], ['наобещать', 0.436], ['предыдущие', 0.376], ['исчезнуть', 0.368], ['вряд', 0.361], ['решаться', 0.297], ['русский', 0.272], ['губернатор', 0.196], ['год', 0.109]]
#
# Комментарий: Ковидный госпиталь когда начнёте строить???
# TF-IDF веса слов в комментарии: [['госпиталь', 0.645], ['ковидный', 0.524], ['строить', 0.431], ['начать', 0.351]]

# %% [markdown]
# Выделение из каждого комментария ключевых слов (или словосочетаний) на основе отобранного содержимого комментариев. В качестве примера осуществляется вывод первых 10 элементов.

# %%
comments_keywords = []
for i in range(len(comments_contents)):
    try:
        content_keywords = nlp.get_keywords_pullenti(comments_contents[i])
        comments_keywords.append(content_keywords)
    except Exception:
        comments_keywords.append([])

n = 10 if len(comments_keywords) >= 10 else len(comments_keywords)
for i in range(n):
    print('Комментарий:', comments_contents[i])
    print('Ключевые слова в комментарии:', comments_keywords[i], end='\n\n')
# Out:
# Комментарий: Алексей Юрьевич,что насчёт канализации на амурской думаете делать,как будем решать проблему?
# Ключевые слова в комментарии: ['ЮРЬЕВИЧ', 'КАНАЛИЗАЦИЯ', 'ДУМАТЬ', 'ДЕЛАТЬ', 'РЕШАТЬ', 'ПРОБЛЕМА']
#
# Комментарий: Как быть тем многодетным которых вообще не ставят на очередь на землю из за того что один ребёнок на территории папы прописан???Глупые критерии!
# Ключевые слова в комментарии: ['ТЕРРИТОРИЯ ПАПЫ', 'ГЛУПЫЙ КРИТЕРИЙ', 'СТАВИТЬ', 'ОЧЕРЕДЬ', 'ЗЕМЛЯ', 'РЕБЕНОК', 'ТЕРРИТОРИЯ', 'ПАПА', 'ПРОПИСАТЬ', 'ГЛУПЫЙ', 'КРИТЕРИЙ']
#
# Комментарий: Остановите ценыыыыыыыы!!!!!!!! Скоро по меру пойдём!😢
# Ключевые слова в комментарии: ['ОСТАНОВИТЬ', 'МЕРА', 'ПОЙТИ']
#
# Комментарий: Соглашусь Остановите цены сегодня зашла с ума сойти капуста 50 руб килограмм в Гулливере сахар за 50 руб перевалил 900 г просто беспредел хлеб дорожает основные виды продуктов, которые мы покупаем это первая необходимость и она недоступна со мной думаю согласятся все особенно пенсионеры🔥🔥🔥
# Ключевые слова в комментарии: ['ОСНОВНЫЙ ВИД ПРОДУКТОВ', 'RUB', 'СОГЛАСИТЬ', 'ОСНОВНЫЙ ВИД', 'ОСТАНОВИТЬ', 'ЦЕНА', 'ЗАЙТИ', 'УМ', 'СОЙТИ', 'КАПУСТА', 'КИЛОГРАММ', 'САХАР', 'ПЕРЕВАЛИТЬ', 'БЕСПРЕДЕЛ', 'ХЛЕБ', 'ДОРОЖАТЬ', 'ОСНОВНЫЙ', 'ВИД', 'ПРОДУКТ', 'ПОКУПАТЬ', 'НЕОБХОДИМОСТЬ', 'ДУМАТЬ', 'ПЕНСИОНЕР', 'RUB']
#
# Комментарий: Добрый вечер, круглосуточная аптека хотя бы одна нужна в дальнем засвияжье. Спасибо за внимание 👋
# Ключевые слова в комментарии: ['ДОБРЫЙ ВЕЧЕР', 'КРУГЛОСУТОЧНАЯ АПТЕКА', 'ДОБРЫЙ', 'ВЕЧЕР', 'КРУГЛОСУТОЧНЫЙ', 'АПТЕКА', 'ХОТЕТЬ', 'СПАСИБО', 'ВНИМАНИЕ']
#
# Комментарий: Землю то не дают. Какие инфраструктуры?
# Ключевые слова в комментарии: ['Земля', 'ДАВАТЬ', 'ИНФРАСТРУКТУРА']
#
# Комментарий: Вы бы эту инфраструктуру сделали в новой жизни! Должна была быть поликлиника! И где она???? Только болтать можете. Огромный район. Из инфраструктуры ноль. А насчёт инфраструктуры где дали земли многодетным. Так когда вообще последний раз вообще её давали??? 7лет назад?
# Ключевые слова в комментарии: ['ИНФРАСТРУКТУРА', 'НОВАЯ ЖИЗНЬ', 'ОГРОМНЫЙ РАЙОН', 'ДАЛЬ ЗЕМЛИ', 'СДЕЛАТЬ', 'НОВЫЙ', 'ЖИЗНЬ', 'ПОЛИКЛИНИКА', 'БОЛТАТЬ', 'ОГРОМНЫЙ', 'РАЙОН', 'НОЛЬ', 'ДАЛЬ', 'ЗЕМЛЯ', 'ПОСЛЕДНИЙ', 'ДАВАТЬ']
#
# Комментарий:  нам дали землю- 15 соток в чистом поле, коммуникаций нет никаких, электричества, воды, газа. Зато налог земельный платим. Одна показуха и все!
# Ключевые слова в комментарии: ['ЧИСТЫЙ ПОЛ', 'ЗЕМЛЯ', 'ЗЕМЕЛЬНЫЙ НАЛОГ', 'ДАЛЬ', 'СОТКА', 'ЧИСТЫЙ', 'ПОЛ', 'КОММУНИКАЦИЯ', 'ЭЛЕКТРИЧЕСТВО', 'ВОДА', 'ГАЗ', 'НАЛОГ', 'ПЛАТИТЬ', 'ПОКАЗУХА']
#
# Комментарий: То что предыдущий губернатор наобещал и исчез, вряд ли вина Русских. Тем более если по 7 лет не решалось
# Ключевые слова в комментарии: ['ПРЕДЫДУЩИЙ ГУБЕРНАТОР', 'ВИНА РУССКИХ', 'ПРЕДЫДУЩИЙ', 'ГУБЕРНАТОР', 'НАОБЕЩАТЬ', 'ИСЧЕЗНУТЬ', 'ВИНА', 'РУССКИЙ', 'ЛЕТ', 'РЕШАТЬ']
#
# Комментарий: Ковидный госпиталь когда начнёте строить???
# Ключевые слова в комментарии: ['КОВИДНЫЙ ГОСПИТАЛЬ', 'КОВИДНЫЙ', 'ГОСПИТАЛЬ', 'НАЧАТЬ', 'СТРОИТЬ']

# %% [markdown]
# **Связывание TF-IDF весов слов комментариев с ключевыми словами, извлечёнными из комментариев.**
#
# Рассматривается ключевое слово (или словосочетание) и ему в соответствие ставится TF-IDF вес (если для такого слова он был посчитан). TF-IDF вес для словосочетаний рассчитывается как сумма TF-IDF весов слов, из которых состоит словосочетание. В качестве примера осуществляется вывод первых 10 элементов.

# %%
# словарь, в котором в качестве ключа выступает id комментария в БД, а в качестве значения - список ключевых слов комментария с указанием их весов tf-idf
comments_with_tf_idf_keywords = {}
# проход по ключевым словам всех комментариев (список, в котором каждый элемент представлен списком ключевых слов комментария)
for i in range(len(comments_keywords)):
    # словарь, в котором хранятся пары вида "ключевое слово - tf-idf вес" для i-го комментария
    comment_keywords_with_ratios = {}
    # проход по ключевым словам i-того комментария (список, в котором каждый элемент представлен либо ключевым словом, либо ключевым словосочетанием)
    for keyword in comments_keywords[i]:
        # проверка, элемент является словом или словосочетанием
        keyphrase_words = keyword.split()
        if len(keyphrase_words) > 1:  # словосочетание
            tf_idf_sum = 0.0
            # проход по словам ключевого словосочетания
            for word in keyphrase_words:
                # лемматизируем слово (получаем его нормальную форму)
                normal_word = nlp.get_normal_form(word)
                for tf_idf_weight in comments_tf_idf_weights[i]:
                    # если для ключевого слова нашёлся его tf-idf вес
                    if normal_word.lower() == tf_idf_weight[0]:
                        tf_idf_sum += tf_idf_weight[1]
                        break
            if tf_idf_sum > 0.0:
                comment_keywords_with_ratios[keyword] = tf_idf_sum
        else:  # слово
            # лемматизируем слово (получаем его нормальную форму)
            normal_word = nlp.get_normal_form(keyword)
            # проход по tf-idf весам слов всех комментариев (список, в котором каждый элемент представлен списком пар "слово-вес")
            for tf_idf_weight in comments_tf_idf_weights[i]:
                # если для ключевого слова нашёлся его tf-idf вес
                if normal_word.lower() == tf_idf_weight[0]:
                    comment_keywords_with_ratios[keyword] = tf_idf_weight[1]
                    break
    # если для ключевых слов комментария нашлись tf-idf веса, то ставим пары "ключевое слово - tf-idf вес" в соответствие комментарию
    if len(comment_keywords_with_ratios) > 0:
        comments_with_tf_idf_keywords[filtered_comments[i].id] = dict(
            sorted(comment_keywords_with_ratios.items(), key=lambda item: item[1], reverse=True)
        )

n = 10 if len(comments_with_tf_idf_keywords) >= 10 else len(comments_with_tf_idf_keywords)
c = 0
for comment_id, comment_keywords in comments_with_tf_idf_keywords.items():
    if c == n:
        break

    print('Комментарий:', db.get_comment(comment_id).text)
    print('Ключевые слова:', comment_keywords, end='\n\n')
    c += 1
# Out:
# Комментарий: Алексей Юрьевич,что насчёт канализации на амурской думаете делать,как будем решать проблему?
# Ключевые слова: {'РЕШАТЬ': 0.341, 'КАНАЛИЗАЦИЯ': 0.332, 'ДУМАТЬ': 0.304, 'ДЕЛАТЬ': 0.242, 'ПРОБЛЕМА': 0.204, 'ЮРЬЕВИЧ': 0.199}
#
# Комментарий: Как быть тем многодетным которых вообще не ставят на очередь на землю из за того что один ребёнок на территории папы прописан???Глупые критерии!
# Ключевые слова: {'ГЛУПЫЙ КРИТЕРИЙ': 0.776, 'ТЕРРИТОРИЯ ПАПЫ': 0.575, 'ГЛУПЫЙ': 0.394, 'КРИТЕРИЙ': 0.382, 'ПАПА': 0.372, 'ПРОПИСАТЬ': 0.372, 'ЗЕМЛЯ': 0.303, 'СТАВИТЬ': 0.29, 'ОЧЕРЕДЬ': 0.203, 'ТЕРРИТОРИЯ': 0.203, 'РЕБЕНОК': 0.148}
#
# Комментарий: Остановите ценыыыыыыыы!!!!!!!! Скоро по меру пойдём!😢
# Ключевые слова: {'ОСТАНОВИТЬ': 0.472, 'МЕРА': 0.264}
#
# Комментарий: Соглашусь Остановите цены сегодня зашла с ума сойти капуста 50 руб килограмм в Гулливере сахар за 50 руб перевалил 900 г просто беспредел хлеб дорожает основные виды продуктов, которые мы покупаем это первая необходимость и она недоступна со мной думаю согласятся все особенно пенсионеры🔥🔥🔥
# Ключевые слова: {'ОСНОВНЫЙ ВИД ПРОДУКТОВ': 0.271, 'ПЕРЕВАЛИТЬ': 0.236, 'КИЛОГРАММ': 0.217, 'ДОРОЖАТЬ': 0.217, 'ЗАЙТИ': 0.199, 'КАПУСТА': 0.199, 'УМ': 0.183, 'САХАР': 0.177, 'ОСТАНОВИТЬ': 0.171, 'ХЛЕБ': 0.161, 'БЕСПРЕДЕЛ': 0.155, 'НЕОБХОДИМОСТЬ': 0.151, 'ПРОДУКТ': 0.15, 'ПОКУПАТЬ': 0.15, 'ПЕНСИОНЕР': 0.138, 'ДУМАТЬ': 0.125, 'ОСНОВНЫЙ ВИД': 0.121, 'ЦЕНА': 0.121, 'ВИД': 0.121}
#
# Комментарий: Добрый вечер, круглосуточная аптека хотя бы одна нужна в дальнем засвияжье. Спасибо за внимание 👋
# Ключевые слова: {'КРУГЛОСУТОЧНАЯ АПТЕКА': 0.875, 'ДОБРЫЙ ВЕЧЕР': 0.477, 'АПТЕКА': 0.446, 'КРУГЛОСУТОЧНЫЙ': 0.429, 'ВЕЧЕР': 0.307, 'ВНИМАНИЕ': 0.229, 'ДОБРЫЙ': 0.17, 'СПАСИБО': 0.169}
#
# Комментарий: Землю то не дают. Какие инфраструктуры?
# Ключевые слова: {'ИНФРАСТРУКТУРА': 0.612, 'Земля': 0.56, 'ДАВАТЬ': 0.466}
#
# Комментарий: Вы бы эту инфраструктуру сделали в новой жизни! Должна была быть поликлиника! И где она???? Только болтать можете. Огромный район. Из инфраструктуры ноль. А насчёт инфраструктуры где дали земли многодетным. Так когда вообще последний раз вообще её давали??? 7лет назад?
# Ключевые слова: {'ИНФРАСТРУКТУРА': 0.643, 'БОЛТАТЬ': 0.303, 'НОЛЬ': 0.205, 'ДАЛЬ ЗЕМЛИ': 0.196, 'ЗЕМЛЯ': 0.196, 'ДАВАТЬ': 0.163, 'НОВАЯ ЖИЗНЬ': 0.151, 'ЖИЗНЬ': 0.151, 'ОГРОМНЫЙ РАЙОН': 0.146, 'ОГРОМНЫЙ': 0.146, 'СДЕЛАТЬ': 0.128, 'ПОЛИКЛИНИКА': 0.115}
#
# Комментарий: @elena_kuleshina нам дали землю- 15 соток в чистом поле, коммуникаций нет никаких, электричества, воды, газа. Зато налог земельный платим. Одна показуха и все!
# Ключевые слова: {'ЗЕМЕЛЬНЫЙ НАЛОГ': 0.45499999999999996, 'СОТКА': 0.385, 'ЭЛЕКТРИЧЕСТВО': 0.324, 'ПОКАЗУХА': 0.299, 'КОММУНИКАЦИЯ': 0.288, 'ЧИСТЫЙ ПОЛ': 0.263, 'ЧИСТЫЙ': 0.263, 'ЗЕМЛЯ': 0.249, 'НАЛОГ': 0.214, 'ВОДА': 0.198, 'ГАЗ': 0.188, 'ПЛАТИТЬ': 0.186}
#
# Комментарий: То что предыдущий губернатор наобещал и исчез, вряд ли вина Русских. Тем более если по 7 лет не решалось
# Ключевые слова: {'ВИНА РУССКИХ': 0.708, 'НАОБЕЩАТЬ': 0.436, 'ВИНА': 0.436, 'ИСЧЕЗНУТЬ': 0.368, 'РУССКИЙ': 0.272, 'ПРЕДЫДУЩИЙ ГУБЕРНАТОР': 0.196, 'ГУБЕРНАТОР': 0.196, 'ЛЕТ': 0.109}
#
# Комментарий: Ковидный госпиталь когда начнёте строить???
# Ключевые слова: {'КОВИДНЫЙ ГОСПИТАЛЬ': 1.169, 'ГОСПИТАЛЬ': 0.645, 'КОВИДНЫЙ': 0.524, 'СТРОИТЬ': 0.431, 'НАЧАТЬ': 0.351}

# %% [markdown]
# Применение функции [softmax](https://www.helenkapatsa.ru/softmaks/) к ключевым словам каждого комментария с целью нормализации tf-idf весов ключевых слов. В качестве примера осуществляется вывод первых 10 элементов.

# %%
import numpy as np

for comment_id, comment_keywords in comments_with_tf_idf_keywords.items():
    # перебор каждой степени i и вычисление экспонент
    exps = [np.exp(i) for i in comment_keywords.values()]
    sum_of_exps = sum(exps)
    softmax = [j / sum_of_exps for j in exps]

    i = 0
    for key in comment_keywords.keys():
        comment_keywords[key] = softmax[i]
        i += 1

n = 10 if len(comments_with_tf_idf_keywords) >= 10 else len(comments_with_tf_idf_keywords)
c = 0
for comment_id, comment_keywords in comments_with_tf_idf_keywords.items():
    if c == n:
        break

    print('Комментарий:', db.get_comment(comment_id).text)
    print('Ключевые слова:', comment_keywords, end='\n\n')
    c += 1
# Out:
# Комментарий: Алексей Юрьевич,что насчёт канализации на амурской думаете делать,как будем решать проблему?
# Ключевые слова: {'РЕШАТЬ': 0.17856981172498693, 'КАНАЛИЗАЦИЯ': 0.17696989384933356, 'ДУМАТЬ': 0.17208346605314348, 'ДЕЛАТЬ': 0.16173830484304486, 'ПРОБЛЕМА': 0.15570755911020503, 'ЮРЬЕВИЧ': 0.15493096441928625}
#
# Комментарий: Как быть тем многодетным которых вообще не ставят на очередь на землю из за того что один ребёнок на территории папы прописан???Глупые критерии!
# Ключевые слова: {'ГЛУПЫЙ КРИТЕРИЙ': 0.13496037017453388, 'ТЕРРИТОРИЯ ПАПЫ': 0.11038576453286196, 'ГЛУПЫЙ': 0.09210978502288764, 'КРИТЕРИЙ': 0.09101107305890879, 'ПАПА': 0.09010549775130604, 'ПРОПИСАТЬ': 0.09010549775130604, 'ЗЕМЛЯ': 0.08409786507302035, 'СТАВИТЬ': 0.08301166840265514, 'ОЧЕРЕДЬ': 0.07609489509500823, 'ТЕРРИТОРИЯ': 0.07609489509500823, 'РЕБЕНОК': 0.07202268804250371}
#
# Комментарий: Остановите ценыыыыыыыы!!!!!!!! Скоро по меру пойдём!😢
# Ключевые слова: {'ОСТАНОВИТЬ': 0.5518133302331701, 'МЕРА': 0.4481866697668298}
#
# Комментарий: Соглашусь Остановите цены сегодня зашла с ума сойти капуста 50 руб килограмм в Гулливере сахар за 50 руб перевалил 900 г просто беспредел хлеб дорожает основные виды продуктов, которые мы покупаем это первая необходимость и она недоступна со мной думаю согласятся все особенно пенсионеры🔥🔥🔥
# Ключевые слова: {'ОСНОВНЫЙ ВИД ПРОДУКТОВ': 0.058073840819898304, 'ПЕРЕВАЛИТЬ': 0.05607641523857356, 'КИЛОГРАММ': 0.055021021340646376, 'ДОРОЖАТЬ': 0.055021021340646376, 'ЗАЙТИ': 0.05403950312133734, 'КАПУСТА': 0.05403950312133734, 'УМ': 0.05318175138392093, 'САХАР': 0.052863616235467634, 'ОСТАНОВИТЬ': 0.0525473841829081, 'ХЛЕБ': 0.05202452897424183, 'БЕСПРЕДЕЛ': 0.051713316371840824, 'НЕОБХОДИМОСТЬ': 0.0515068762618269, 'ПРОДУКТ': 0.05145539513042086, 'ПОКУПАТЬ': 0.05145539513042086, 'ПЕНСИОНЕР': 0.05084162040250238, 'ДУМАТЬ': 0.05018495689803387, 'ОСНОВНЫЙ ВИД': 0.049984618015325596, 'ЦЕНА': 0.049984618015325596, 'ВИД': 0.049984618015325596}
#
# Комментарий: Добрый вечер, круглосуточная аптека хотя бы одна нужна в дальнем засвияжье. Спасибо за внимание 👋
# Ключевые слова: {'КРУГЛОСУТОЧНАЯ АПТЕКА': 0.1983526896791956, 'ДОБРЫЙ ВЕЧЕР': 0.13322596974214188, 'АПТЕКА': 0.1291593233643723, 'КРУГЛОСУТОЧНЫЙ': 0.12698217307740076, 'ВЕЧЕР': 0.1123980633283795, 'ВНИМАНИЕ': 0.10396421019113895, 'ДОБРЫЙ': 0.09800776469725822, 'СПАСИБО': 0.0979098059201128}
#
# Комментарий: Землю то не дают. Какие инфраструктуры?
# Ключевые слова: {'ИНФРАСТРУКТУРА': 0.35543087735094964, 'Земля': 0.3374207920365511, 'ДАВАТЬ': 0.30714833061249913}
#
# Комментарий: Вы бы эту инфраструктуру сделали в новой жизни! Должна была быть поликлиника! И где она???? Только болтать можете. Огромный район. Из инфраструктуры ноль. А насчёт инфраструктуры где дали земли многодетным. Так когда вообще последний раз вообще её давали??? 7лет назад?
# Ключевые слова: {'ИНФРАСТРУКТУРА': 0.12687518404868953, 'БОЛТАТЬ': 0.09030599070090124, 'НОЛЬ': 0.08187582747138389, 'ДАЛЬ ЗЕМЛИ': 0.08114225106958356, 'ЗЕМЛЯ': 0.08114225106958356, 'ДАВАТЬ': 0.07850825672167647, 'НОВАЯ ЖИЗНЬ': 0.07757178769279105, 'ЖИЗНЬ': 0.07757178769279105, 'ОГРОМНЫЙ РАЙОН': 0.07718489678761242, 'ОГРОМНЫЙ': 0.07718489678761242, 'СДЕЛАТЬ': 0.0758079979113903, 'ПОЛИКЛИНИКА': 0.07482887204598447}
#
# Комментарий: @elena_kuleshina нам дали землю- 15 соток в чистом поле, коммуникаций нет никаких, электричества, воды, газа. Зато налог земельный платим. Одна показуха и все!
# Ключевые слова: {'ЗЕМЕЛЬНЫЙ НАЛОГ': 0.09935574380928767, 'СОТКА': 0.09263868149993851, 'ЭЛЕКТРИЧЕСТВО': 0.08715662445735005, 'ПОКАЗУХА': 0.08500471973218449, 'КОММУНИКАЦИЯ': 0.08407479179553648, 'ЧИСТЫЙ ПОЛ': 0.08199897778990507, 'ЧИСТЫЙ': 0.08199897778990507, 'ЗЕМЛЯ': 0.08085899063069035, 'НАЛОГ': 0.07807787930611441, 'ВОДА': 0.07683857411712638, 'ГАЗ': 0.0760740175301841, 'ПЛАТИТЬ': 0.07592202154177748}
#
# Комментарий: То что предыдущий губернатор наобещал и исчез, вряд ли вина Русских. Тем более если по 7 лет не решалось
# Ключевые слова: {'ВИНА РУССКИХ': 0.17761835168827075, 'НАОБЕЩАТЬ': 0.13531929808146242, 'ВИНА': 0.13531929808146242, 'ИСЧЕЗНУТЬ': 0.12642347150972322, 'РУССКИЙ': 0.1148511746530708, 'ПРЕДЫДУЩИЙ ГУБЕРНАТОР': 0.10644593001084815, 'ГУБЕРНАТОР': 0.10644593001084815, 'ЛЕТ': 0.0975765459643141}
#
# Комментарий: Ковидный госпиталь когда начнёте строить???
# Ключевые слова: {'КОВИДНЫЙ ГОСПИТАЛЬ': 0.32935990739339527, 'ГОСПИТАЛЬ': 0.1950295520957369, 'КОВИДНЫЙ': 0.1728028062810108, 'СТРОИТЬ': 0.1574567939161901, 'НАЧАТЬ': 0.14535094031366688}
